# %%
import numpy
import os

# %%
for file in os.listdir('./UCR'):
    print(file)
    with open('./UCR'+file+'/'+file+'_TRAIN.tsv') as fin:
        lines = len(fin.readlines())
    print(file,lines)
# Out:
# FacesUCR
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-c71004834b2c> in <module>
#       1 for file in os.listdir('./UCR'):
#       2     print(file)
# ----> 3     with open(file+'/'+file+'_TRAIN.tsv') as fin:
#       4         lines = len(fin.readlines())
#       5     print(file,lines)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'FacesUCR/FacesUCR_TRAIN.tsv'
